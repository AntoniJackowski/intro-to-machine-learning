# %%
from os import remove

import pandas as pd
from pandas import isnull
from requests import delete

# %%
pd.DataFrame({'Yes': [12, 53], 'No': [432, 1]})
# Out:
#    Yes   No
# 0   12  432
# 1   53    1

# %%
pd.DataFrame({0: ['yes', 'no'], 1: ['yes', 'no']})
# Out:
#      0    1
# 0  yes  yes
# 1   no   no

# %%
pd.DataFrame({'Cat': ['no', 'yes'], 'Dog': ['yes', 'no']}, index=['Likes water', 'Eat Fish'])
# Out:
#              Cat  Dog
# Likes water   no  yes
# Eat Fish     yes   no

# %%
pd.Series([1, 2, 3, 4, 5, 6])
# Out:
# 0    1
# 1    2
#     ..
# 4    5
# 5    6
# Length: 6, dtype: int64

# %%
pd.Series([52, 64, 58], index=['2023 Sales', '2024 Sales', '2025 Sales'], name='Product A')
# Out:
# 2023 Sales    52
# 2024 Sales    64
# 2025 Sales    58
# Name: Product A, dtype: int64

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("zynicide/wine-reviews")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\Antek\.cache\kagglehub\datasets\zynicide\wine-reviews\versions\4

# %%
import os

csv_file_path = os.path.join(path, "winemag-data-130k-v2.csv")

wine_reviews = pd.read_csv(csv_file_path, index_col=0)

wine_reviews.shape
# Out:
# (129971, 13)

# %%
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
pd.set_option('display.max_rows', 5)

# %%
set(wine_reviews.country)
# Out:
# {'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Bulgaria',
#  'Canada',
#  'Chile',
#  'China',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Egypt',
#  'England',
#  'France',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'India',
#  'Israel',
#  'Italy',
#  'Lebanon',
#  'Luxembourg',
#  'Macedonia',
#  'Mexico',
#  'Moldova',
#  'Morocco',
#  'New Zealand',
#  'Peru',
#  'Portugal',
#  'Romania',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'South Africa',
#  'Spain',
#  'Switzerland',
#  'Turkey',
#  'US',
#  'Ukraine',
#  'Uruguay',
#  nan}

# %%
wine_reviews.loc[wine_reviews.price.notnull()]
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price province  \
# 1                            Avidagos      87   15.0    Douro
# 2                                 NaN      87   14.0   Oregon
# ...                               ...     ...    ...      ...
# 129969                            NaN      90   32.0   Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#                  region_1           region_2   taster_name  \
# 1                     NaN                NaN    Roger Voss
# 2       Willamette Valley  Willamette Valley  Paul Gregutt
# ...

# %%
wine_reviews['critic'] = 'everyone'

# %%
wine_reviews.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# winery                                                   Nicosia
# critic                                                  everyone
# Name: 0, Length: 14, dtype: object

# %%
import numpy as np

# %%
wine_reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
wine_reviews_points_mean = wine_reviews.points.mean()
wine_reviews.points.map(lambda p : p - wine_reviews_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
wine_reviews.title[15]
# Out:
# 'Richard Böcking 2013 Devon Riesling (Mosel)'

# %%
tropical_occurs = wine_reviews.description.map(lambda d : d.count('tropical'))
tropical_counter = sum(tropical_occurs)
fruity_occurs = wine_reviews.description.map(lambda d : d.count('fruity'))
fruity_counter = sum(fruity_occurs)

# %%
wine_reviews.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery', 'critic'],
#       dtype='str')

# %%
wine_reviews.taster_twitter_handle.replace('@kerinokeefe', '@kerino')
# Out:
# 0            @kerino
# 1         @vossroger
#              ...
# 129969    @vossroger
# 129970    @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: str

# %%
wine_reviews.isnull().any()
# Out:
# country         True
# description    False
#                ...
# winery         False
# critic         False
# Length: 14, dtype: bool
